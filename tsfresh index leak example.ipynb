# %%
# %load classifier.py
# get_ipython().magic('matplotlib inline')
from sklearn.model_selection import KFold
from sklearn.neighbors import  KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import numpy as np
import input_parser
import features as ft
import pandas as pd

def main():

    input_data, labels = input_parser.parse_input()
    X, Y = ft.get_features(input_data, labels)

    print("X.columns:")
    print(X.columns)

    folds = 5
    print("Selecting rows for " + str(folds) + "-fold validation")
    kf = KFold(n_splits=folds)
    kf.get_n_splits(X)

    summed_accuracy = 0

    fold_cnt = 1
    for train_index, test_index in kf.split(X):

        print('Fold: ' + str(fold_cnt))
        X_train, X_test = X.loc[train_index,], X.loc[test_index,]
        Y_train, Y_test = Y[train_index], Y[test_index]
        print(X_train)
        model = KNeighborsClassifier(n_neighbors=3)
        model.fit(X_train,Y_train)
        predictions = model.predict(X_test)

        summed_accuracy += accuracy_score(Y_test, predictions)
        print(confusion_matrix(Y_test,predictions))
        print(classification_report(Y_test,predictions))
        fold_cnt += 1

    print("Total accuracy: " + str(summed_accuracy / folds))

main()
# Out:
# Parse input files...
# binary_test/binary_test.txt
# {' target_class_1': 1, ' target_class_2': 2}
#      id  time  value
# 0     0     1    760
# 1     0    11    761
# 2     0   466    761
# 3     0   473    765
# 4     0   481    763
# 5     0   488    761
# 6     0   516    763
# 7     0   532    763
# 8     0   542    756
# 9     1     1    760
# 10    1    11    761
# 11    1   466    761
# 12    1   473    765
# 13    1   481    763
# 14    1   488    761
# 15    1   516    763
# 16    1   532    763
# 17    1   542    756
# 18    2     1    760
# 19    2    11    761
# 20    2   466    761
# 21    2   473    765
# 22    2   481    763
# 23    2   488    761
# 24    2   516    763
# 25    2   532    763
# 26    2   542    756
# 27    3     1    760
# 28    3    11    761
# 29    3   466    761
# ..   ..   ...    ...
# 303  33   516    763
# 304  33   532    763
# 305  33   542    756
# 306  34     1    760
# 307  34    11    761
# 308  34   466    761
# 309  34   473    765
# 310  34   481    763
# 311  34   488    761
# 312  34   516    763
# 313  34   532    763
# 314  34   542    756
# 315  35     1    760
# 316  35    11    761
# 317  35   466    761
# 318  35   473    765
# 319  35   481    763
# 320  35   488    761
# 321  35   516    763
# 322  35   532    763
# 323  35   542    756
# 324  36     1    760
# 325  36    11    761
# 326  36   466    761
# 327  36   473    765
# 328  36   481    763
# 329  36   488    761
# 330  36   516    763
# 331  36   532    763
# 332  36   542    756
#
# [333 rows x 3 columns]
# Feature Extraction: 100%|██████████| 1/1 [00:04<00:00,  4.48s/it]
# WARNING:tsfresh.utilities.dataframe_functions:The columns ['value__autocorrelation__lag_8' 'value__autocorrelation__lag_9'
#  'value__max_langevin_fixed_point__m_3__r_30'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_2'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_2'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_2'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_2'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_5'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_5'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_10'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_10'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20'
#  'value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20'
#  'value__spkt_welch_density__coeff_5' 'value__spkt_welch_density__coeff_8'
#  'value__ar_coefficient__k_10__coeff_0'
#  'value__ar_coefficient__k_10__coeff_1'
#  'value__ar_coefficient__k_10__coeff_2'
#  'value__ar_coefficient__k_10__coeff_3'
#  'value__ar_coefficient__k_10__coeff_4'
#  'value__friedrich_coefficients__m_3__r_30__coeff_3'
#  'value__friedrich_coefficients__m_3__r_30__coeff_2'
#  'value__friedrich_coefficients__m_3__r_30__coeff_1'
#  'value__friedrich_coefficients__m_3__r_30__coeff_0'] did not have any finite values. Filling with zeros.
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_9 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__variance is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__approximate_entropy__m_2__r_0.1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__time_reversal_asymmetry_statistic__lag_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__sum_of_reoccurring_data_points is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.35000000000000003 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_5 is constant
# Feature Selection:   0%|          | 0/222 [00:00<?, ?it/s]WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__minimum is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.55 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__last_location_of_maximum is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.25 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.15000000000000002 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.35000000000000003 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.2__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__abs_energy is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.6000000000000001 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__approximate_entropy__m_2__r_0.3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_1.0__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__friedrich_coefficients__m_3__r_30__coeff_0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__count_above_mean is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.2__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__ar_coefficient__k_10__coeff_3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__first_location_of_maximum is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__number_peaks__n_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.8__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.4__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__last_location_of_minimum is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_number_of_peaks__n_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__has_duplicate_min is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__has_duplicate is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.7 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_9 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.6__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__percentage_of_reoccurring_values_to_all_values is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.6__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__ar_coefficient__k_10__coeff_4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__median is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_number_of_peaks__n_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.15000000000000002 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_1.0__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__longest_strike_below_mean is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.8__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__skewness is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.6 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__value_count__value_0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_1.0__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__max_langevin_fixed_point__m_3__r_30 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.8__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2 is constant
# Feature Selection:  22%|██▏       | 49/222 [00:00<00:00, 374.69it/s]WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.2__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__length is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__has_duplicate_max is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__first_location_of_minimum is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__value_count__value_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__binned_entropy__max_bins_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__longest_strike_above_mean is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.05 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__number_peaks__n_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.7000000000000001 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.4__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.4__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_20 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_change is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.2__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__number_cwt_peaks__n_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.30000000000000004 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_number_of_peaks__n_3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__approximate_entropy__m_2__r_0.9 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_6 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__number_cwt_peaks__n_1 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_1.0__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__spkt_welch_density__coeff_8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.4__ql_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__approximate_entropy__m_2__r_0.5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__standard_deviation is constant
# Feature Selection:  49%|████▉     | 109/222 [00:00<00:00, 418.87it/s]WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.2__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.6__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_second_derivate_central is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.8500000000000001 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.9 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.65 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__value_count__value_-inf is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__friedrich_coefficients__m_3__r_30__coeff_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.9500000000000001 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__value_count__value_inf is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_7 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__sample_entropy is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__sum_values is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.75 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__maximum is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20 is constant
# WARNING:tsfresh.feature_selection.significance_tests:[target_binary_feature_binary_test] The binary target should have values 1 and 0 (or True and False). Instead found{1.0, 2.0}
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.8__ql_0.0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__variance_larger_than_standard_deviation is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__ar_coefficient__k_10__coeff_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.4__ql_0.8 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__ar_coefficient__k_10__coeff_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__friedrich_coefficients__m_3__r_30__coeff_3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__absolute_sum_of_changes is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__sum_of_reoccurring_values is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.45 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__number_peaks__n_3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.6__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__kurtosis is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.4 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__approximate_entropy__m_2__r_0.7 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.45 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.25 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_6 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__friedrich_coefficients__m_3__r_30__coeff_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__value_count__value_nan is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__ratio_value_number_to_time_series_length is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__ar_coefficient__k_10__coeff_0 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__time_reversal_asymmetry_statistic__lag_1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.30000000000000004 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__augmented_dickey_fuller is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__time_reversal_asymmetry_statistic__lag_3 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.8__ql_0.6 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__autocorrelation__lag_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.1 is constant
# Feature Selection:  71%|███████   | 157/222 [00:00<00:00, 435.19it/s]WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__spkt_welch_density__coeff_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_autocorrelation is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__count_below_mean is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__symmetry_looking__r_0.1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__quantile__q_0.9 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__large_standard_deviation__r_0.05 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__range_count__max_1__min_-1 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_5 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_20 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__fft_coefficient__coeff_7 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__percentage_of_reoccurring_datapoints_to_all_datapoints is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_1.0__ql_0.2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_10 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__spkt_welch_density__coeff_2 is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean is constant
# WARNING:tsfresh.feature_selection.feature_selector:[test_feature_significance] Feature value__mean_abs_change_quantiles__qh_0.6__ql_0.0 is constant
# Feature Selection: 100%|██████████| 222/222 [00:00<00:00, 588.85it/s]
#     value__index_mass_quantile__q_0.7  value__index_mass_quantile__q_0.3  \
# id
# 0                            0.777778                           0.333333
# 1                            1.777778                           1.333333
# 2                            2.777778                           2.333333
# 3                            3.777778                           3.333333
# 4                            4.777778                           4.333333
# 5                            5.777778                           5.333333
# 6                            6.777778                           6.333333
# 7                            7.777778                           7.333333
# 8                            8.777778                           8.333333
# 9                            9.777778                           9.333333
# 10                          10.777778                          10.333333
# 11                          11.777778                          11.333333
# 12                          12.777778                          12.333333
# 13                          13.777778                          13.333333
# 14                          14.777778                          14.333333
# 15                          15.777778                          15.333333
# 16                          16.777778                          16.333333
# 17                          17.777778                          17.333333
# 18                          18.777778                          18.333333
# 19                          19.777778                          19.333333
# 20                          20.777778                          20.333333
# 21                          21.777778                          21.333333
# 22                          22.777778                          22.333333
# 23                          23.777778                          23.333333
# 24                          24.777778                          24.333333
# 25                          25.777778                          25.333333
# 26                          26.777778                          26.333333
# 27                          27.777778                          27.333333
# 28                          28.777778                          28.333333
# 29                          29.777778                          29.333333
# 30                          30.777778                          30.333333
# 31                          31.777778                          31.333333
# 32                          32.777778                          32.333333
# 33                          33.777778                          33.333333
# 34                          34.777778                          34.333333
# 35                          35.777778                          35.333333
# 36                          36.777778                          36.333333
#
#     value__index_mass_quantile__q_0.8  value__index_mass_quantile__q_0.6  \
# id
# 0                            0.888889                           0.666667
# 1                            1.888889                           1.666667
# 2                            2.888889                           2.666667
# 3                            3.888889                           3.666667
# 4                            4.888889                           4.666667
# 5                            5.888889                           5.666667
# 6                            6.888889                           6.666667
# 7                            7.888889                           7.666667
# 8                            8.888889                           8.666667
# 9                            9.888889                           9.666667
# 10                          10.888889                          10.666667
# 11                          11.888889                          11.666667
# 12                          12.888889                          12.666667
# 13                          13.888889                          13.666667
# 14                          14.888889                          14.666667
# 15                          15.888889                          15.666667
# 16                          16.888889                          16.666667
# 17                          17.888889                          17.666667
# 18                          18.888889                          18.666667
# 19                          19.888889                          19.666667
# 20                          20.888889                          20.666667
# 21                          21.888889                          21.666667
# 22                          22.888889                          22.666667
# 23                          23.888889                          23.666667
# 24                          24.888889                          24.666667
# 25                          25.888889                          25.666667
# 26                          26.888889                          26.666667
# 27                          27.888889                          27.666667
# 28                          28.888889                          28.666667
# 29                          29.888889                          29.666667
# 30                          30.888889                          30.666667
# 31                          31.888889                          31.666667
# 32                          32.888889                          32.666667
# 33                          33.888889                          33.666667
# 34                          34.888889                          34.666667
# 35                          35.888889                          35.666667
# 36                          36.888889                          36.666667
#
#     value__index_mass_quantile__q_0.9  value__index_mass_quantile__q_0.2  \
# id
# 0                                 1.0                           0.222222
# 1                                 2.0                           1.222222
# 2                                 3.0                           2.222222
# 3                                 4.0                           3.222222
# 4                                 5.0                           4.222222
# 5                                 6.0                           5.222222
# 6                                 7.0                           6.222222
# 7                                 8.0                           7.222222
# 8                                 9.0                           8.222222
# 9                                10.0                           9.222222
# 10                               11.0                          10.222222
# 11                               12.0                          11.222222
# 12                               13.0                          12.222222
# 13                               14.0                          13.222222
# 14                               15.0                          14.222222
# 15                               16.0                          15.222222
# 16                               17.0                          16.222222
# 17                               18.0                          17.222222
# 18                               19.0                          18.222222
# 19                               20.0                          19.222222
# 20                               21.0                          20.222222
# 21                               22.0                          21.222222
# 22                               23.0                          22.222222
# 23                               24.0                          23.222222
# 24                               25.0                          24.222222
# 25                               26.0                          25.222222
# 26                               27.0                          26.222222
# 27                               28.0                          27.222222
# 28                               29.0                          28.222222
# 29                               30.0                          29.222222
# 30                               31.0                          30.222222
# 31                               32.0                          31.222222
# 32                               33.0                          32.222222
# 33                               34.0                          33.222222
# 34                               35.0                          34.222222
# 35                               36.0                          35.222222
# 36                               37.0                          36.222222
#
#     value__index_mass_quantile__q_0.1  value__index_mass_quantile__q_0.4
# id
# 0                            0.111111                           0.444444
# 1                            1.111111                           1.444444
# 2                            2.111111                           2.444444
# 3                            3.111111                           3.444444
# 4                            4.111111                           4.444444
# 5                            5.111111                           5.444444
# 6                            6.111111                           6.444444
# 7                            7.111111                           7.444444
# 8                            8.111111                           8.444444
# 9                            9.111111                           9.444444
# 10                          10.111111                          10.444444
# 11                          11.111111                          11.444444
# 12                          12.111111                          12.444444
# 13                          13.111111                          13.444444
# 14                          14.111111                          14.444444
# 15                          15.111111                          15.444444
# 16                          16.111111                          16.444444
# 17                          17.111111                          17.444444
# 18                          18.111111                          18.444444
# 19                          19.111111                          19.444444
# 20                          20.111111                          20.444444
# 21                          21.111111                          21.444444
# 22                          22.111111                          22.444444
# 23                          23.111111                          23.444444
# 24                          24.111111                          24.444444
# 25                          25.111111                          25.444444
# 26                          26.111111                          26.444444
# 27                          27.111111                          27.444444
# 28                          28.111111                          28.444444
# 29                          29.111111                          29.444444
# 30                          30.111111                          30.444444
# 31                          31.111111                          31.444444
# 32                          32.111111                          32.444444
# 33                          33.111111                          33.444444
# 34                          34.111111                          34.444444
# 35                          35.111111                          35.444444
# 36                          36.111111                          36.444444
# X.columns:
# Index(['value__index_mass_quantile__q_0.7',
#        'value__index_mass_quantile__q_0.3',
#        'value__index_mass_quantile__q_0.8',
#        'value__index_mass_quantile__q_0.6',
#        'value__index_mass_quantile__q_0.9',
# ...
# 16                          16.888889                          16.666667
# 17                          17.888889                          17.666667
# 18                          18.888889                          18.666667
# 19                          19.888889                          19.666667
# 20                          20.888889                          20.666667
# 21                          21.888889                          21.666667
# 22                          22.888889                          22.666667
# 30                          30.888889                          30.666667
# 31                          31.888889                          31.666667
# 32                          32.888889                          32.666667
# 33                          33.888889                          33.666667
# 34                          34.888889                          34.666667
# 35                          35.888889                          35.666667
# 36                          36.888889                          36.666667
#
#     value__index_mass_quantile__q_0.9  value__index_mass_quantile__q_0.2  \
# id
# 0                                 1.0                           0.222222
# 1                                 2.0                           1.222222
# 2                                 3.0                           2.222222
# 3                                 4.0                           3.222222
# 4                                 5.0                           4.222222
# 5                                 6.0                           5.222222
# 6                                 7.0                           6.222222
# 7                                 8.0                           7.222222
# 8                                 9.0                           8.222222
# 9                                10.0                           9.222222
# 10                               11.0                          10.222222
# 11                               12.0                          11.222222
# 12                               13.0                          12.222222
# 13                               14.0                          13.222222
# 14                               15.0                          14.222222
# 15                               16.0                          15.222222
# 16                               17.0                          16.222222
# 17                               18.0                          17.222222
# 18                               19.0                          18.222222
# 19                               20.0                          19.222222
# 20                               21.0                          20.222222
# 21                               22.0                          21.222222
# 22                               23.0                          22.222222
# 30                               31.0                          30.222222
# 31                               32.0                          31.222222
# 32                               33.0                          32.222222
# 33                               34.0                          33.222222
# 34                               35.0                          34.222222
# 35                               36.0                          35.222222
# 36                               37.0                          36.222222
#
#     value__index_mass_quantile__q_0.1  value__index_mass_quantile__q_0.4
# id
# 0                            0.111111                           0.444444
# 1                            1.111111                           1.444444
# 2                            2.111111                           2.444444
# 3                            3.111111                           3.444444
# 4                            4.111111                           4.444444
# 5                            5.111111                           5.444444
# 6                            6.111111                           6.444444
# 7                            7.111111                           7.444444
# 8                            8.111111                           8.444444
# 9                            9.111111                           9.444444
# 10                          10.111111                          10.444444
# 11                          11.111111                          11.444444
# 12                          12.111111                          12.444444
# 13                          13.111111                          13.444444
# 14                          14.111111                          14.444444
# 15                          15.111111                          15.444444
# 16                          16.111111                          16.444444
# 17                          17.111111                          17.444444
# 18                          18.111111                          18.444444
# 19                          19.111111                          19.444444
# 20                          20.111111                          20.444444
# 21                          21.111111                          21.444444
# 22                          22.111111                          22.444444
# 30                          30.111111                          30.444444
# 31                          31.111111                          31.444444
# 32                          32.111111                          32.444444
# 33                          33.111111                          33.444444
# 34                          34.111111                          34.444444
# 35                          35.111111                          35.444444
# 36                          36.111111                          36.444444
# [[7]]
#                  precision    recall  f1-score   support
#
#  target_class_2       1.00      1.00      1.00         7
#
#     avg / total       1.00      1.00      1.00         7
#
# Fold: 5
#     value__index_mass_quantile__q_0.7  value__index_mass_quantile__q_0.3  \
# id
# 0                            0.777778                           0.333333
# 1                            1.777778                           1.333333
# 2                            2.777778                           2.333333
# 3                            3.777778                           3.333333
# 4                            4.777778                           4.333333
# 5                            5.777778                           5.333333
# 6                            6.777778                           6.333333
# 7                            7.777778                           7.333333
# 8                            8.777778                           8.333333
# 9                            9.777778                           9.333333
# 10                          10.777778                          10.333333
# 11                          11.777778                          11.333333
# 12                          12.777778                          12.333333
# 13                          13.777778                          13.333333
# 14                          14.777778                          14.333333
# 15                          15.777778                          15.333333
# 16                          16.777778                          16.333333
# 17                          17.777778                          17.333333
# 18                          18.777778                          18.333333
# 19                          19.777778                          19.333333
# 20                          20.777778                          20.333333
# 21                          21.777778                          21.333333
# 22                          22.777778                          22.333333
# 23                          23.777778                          23.333333
# 24                          24.777778                          24.333333
# 25                          25.777778                          25.333333
# 26                          26.777778                          26.333333
# 27                          27.777778                          27.333333
# 28                          28.777778                          28.333333
# 29                          29.777778                          29.333333
#
#     value__index_mass_quantile__q_0.8  value__index_mass_quantile__q_0.6  \
# id
# 0                            0.888889                           0.666667
# 1                            1.888889                           1.666667
# 2                            2.888889                           2.666667
# 3                            3.888889                           3.666667
# 4                            4.888889                           4.666667
# 5                            5.888889                           5.666667
# 6                            6.888889                           6.666667
# 7                            7.888889                           7.666667
# 8                            8.888889                           8.666667
# 9                            9.888889                           9.666667
# 10                          10.888889                          10.666667
# 11                          11.888889                          11.666667
# 12                          12.888889                          12.666667
# 13                          13.888889                          13.666667
# 14                          14.888889                          14.666667
# 15                          15.888889                          15.666667
# 16                          16.888889                          16.666667
# 17                          17.888889                          17.666667
# 18                          18.888889                          18.666667
# 19                          19.888889                          19.666667
# 20                          20.888889                          20.666667
# 21                          21.888889                          21.666667
# 22                          22.888889                          22.666667
# 23                          23.888889                          23.666667
# 24                          24.888889                          24.666667
# 25                          25.888889                          25.666667
# 26                          26.888889                          26.666667
# 27                          27.888889                          27.666667
# 28                          28.888889                          28.666667
# 29                          29.888889                          29.666667
#
#     value__index_mass_quantile__q_0.9  value__index_mass_quantile__q_0.2  \
# id
# 0                                 1.0                           0.222222
# 1                                 2.0                           1.222222
# 2                                 3.0                           2.222222
# 3                                 4.0                           3.222222
# 4                                 5.0                           4.222222
# 5                                 6.0                           5.222222
# 6                                 7.0                           6.222222
# 7                                 8.0                           7.222222
# 8                                 9.0                           8.222222
# 9                                10.0                           9.222222
# 10                               11.0                          10.222222
# 11                               12.0                          11.222222
# 12                               13.0                          12.222222
# 13                               14.0                          13.222222
# 14                               15.0                          14.222222
# 15                               16.0                          15.222222
# 16                               17.0                          16.222222
# 17                               18.0                          17.222222
# 18                               19.0                          18.222222
# 19                               20.0                          19.222222
# 20                               21.0                          20.222222
# 21                               22.0                          21.222222
# 22                               23.0                          22.222222
# 23                               24.0                          23.222222
# 24                               25.0                          24.222222
# 25                               26.0                          25.222222
# 26                               27.0                          26.222222
# 27                               28.0                          27.222222
# 28                               29.0                          28.222222
# 29                               30.0                          29.222222
#
#     value__index_mass_quantile__q_0.1  value__index_mass_quantile__q_0.4
# id
# 0                            0.111111                           0.444444
# 1                            1.111111                           1.444444
# 2                            2.111111                           2.444444
# 3                            3.111111                           3.444444
# 4                            4.111111                           4.444444
# 5                            5.111111                           5.444444
# 6                            6.111111                           6.444444
# 7                            7.111111                           7.444444
# 8                            8.111111                           8.444444
# 9                            9.111111                           9.444444
# 10                          10.111111                          10.444444
# 11                          11.111111                          11.444444
# 12                          12.111111                          12.444444
# 13                          13.111111                          13.444444
# 14                          14.111111                          14.444444
# 15                          15.111111                          15.444444
# 16                          16.111111                          16.444444
# 17                          17.111111                          17.444444
# 18                          18.111111                          18.444444
# 19                          19.111111                          19.444444
# 20                          20.111111                          20.444444
# 21                          21.111111                          21.444444
# 22                          22.111111                          22.444444
# 23                          23.111111                          23.444444
# 24                          24.111111                          24.444444
# 25                          25.111111                          25.444444
# 26                          26.111111                          26.444444
# 27                          27.111111                          27.444444
# 28                          28.111111                          28.444444
# 29                          29.111111                          29.444444
# [[7]]
#                  precision    recall  f1-score   support
#
#  target_class_2       1.00      1.00      1.00         7
#
#     avg / total       1.00      1.00      1.00         7
#
# Total accuracy: 0.942857142857

# %%
# %load input_parser.py
import os, glob

def parse_input():
    
    print('Parse input files...')

    session_dir = 'binary_test'
    file_endings = '*.txt'

    # Top level cells (containing all files)
    input_data = []
    label_names = []

    first_file = True
    for file in glob.glob(os.path.join(session_dir, file_endings)):
        print(file)

        # Mid level cells(containing all the content of a file)
        values = []
        line_cnt = 0

        with open(file) as f:
            for line in f:

                # Low level cells(contain recorded traces)
                line_token = line.split(',')
                record_values = []

                number_of_data_points = len(line_token) - 2 # skip the label name at the last position
                for entry_cnt in range(0, number_of_data_points):

                    entry = line_token[entry_cnt].split('|')
                    value = int(entry[0]) # actual value
                    time_stamp = int(entry[1]) # relative time stamp
                    record_values.append([value, time_stamp])

                current_label = line_token[number_of_data_points]
                if first_file:
                    label_names.append(current_label)
                else:
                    if current_label != label_names[line_cnt]:
                        error_message = ('label name line mismatch - input files do not fit together')
                        raise ValueError(error_message)

                values.append(record_values)

                line_cnt += 1

            input_data.append([str(file), values])

        first_file = False

    #print(input_data)
    #print(label_names)
    return input_data, label_names

# %%
# %load features.py
from tsfresh.examples import load_robot_execution_failures
from tsfresh.examples import download_robot_execution_failures
from tsfresh import select_features
from tsfresh import extract_features
from tsfresh.utilities.dataframe_functions import impute
import pandas as pd
import numpy as np

def get_features(input_data, labels):

    used_records = input_data[0][1]

    time_series, target_classes = construct_tkfresh_input(used_records, labels)
    #download_robot_execution_failures()
    #time_series, Y = load_robot_execution_failures()

    print(time_series)

    extracted_features = extract_features(time_series, column_id='id', column_sort='time', column_value='value')
    impute(extracted_features)
    X = select_features(extracted_features, target_classes)
    print(X)

    Y = pd.Series(labels)
    return X, Y

def construct_tkfresh_input(file_record, labels):

    label_mapping = {}
    label_id = 0
    for item in labels:
        if label_id > 0 and item in label_mapping:
            continue
        else:
            label_id += 1
            label_mapping[item] = label_id
    print(label_mapping)

    id_to_target = []
    df_rows = []

    cur_id = 0
    for trace in file_record:
        id_to_target.append(label_mapping[labels[cur_id]])
        for point in trace:
            time_stamp = point[1]
            value = point[0]
            df_rows.append([cur_id, time_stamp, value])
        cur_id += 1

    df = pd.DataFrame(df_rows, columns=['id', 'time', 'value'])
    #y = pd.Series(id_to_target)
    y = np.array(id_to_target)
    return df, y

# %%
# %load binary_test/binary_test.txt
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_2,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0959f7faff70> in <module>()
#       1 # %load binary_test/binary_test.txt
# ----> 2 760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
#       3 760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
#       4 760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
#       5 760|1, 761|11, 761|466, 765|473, 763|481, 761|488, 763|516, 763|532, 756|542, target_class_1,
#
# NameError: name 'target_class_1' is not defined
